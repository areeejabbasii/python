# %% [markdown]
# <a href="https://colab.research.google.com/github/areeejabbasii/abbasi/blob/main/pythjonlearningonline3rdclass3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#boolean
is_loggedin=True
is_raining=False
is_internet=False
print(is_loggedin)
print(is_raining)
print(is_internet)
# Out:
# True
# False
# False

# %%
#assign
a=34
b=78
print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# True
# False

# %%
#input example
name=input("enter your name")
print("hello",name)
# Out:
# enter your nameAREEJ SAFEER
# hello AREEJ SAFEER

# %%
age_limit=18
my_age=14
print(my_age==age_limit) #false
# == equal >=,<=
# Out:
# False

# %%
areej_age=19
if(areej_age>18):
 print("you are allowed")
#alterane kuch hona chaii jb false ho
else:
  print("youare not ")
# Out:
# you are allowed

# %%
 #input
name=input("whats your name?")
print("hello,"+name+"!")

# %%
age=int(input("enter your age:"))
if(age<18):
 print("you are mnior")
elif(age>18):
  print("you are 18")
else:
  print("your an adult")
# Out:
# enter your age:45
# you are 18

# %%
name=input("apka name kiya ha")
print("hello",name,"!")
# Out:
# apka name kiya haareej
# hello areej !

# %%
#logical operator
age=int(input("enter your age:"))
weight=int(input("enter your weight:"))
if(age<18):
  print("you are minor")
elif(age==18 and weight<=80):
  print("you are old")
else:
  print("you are over weight")
# Out:
# enter your age:19
# enter your weight:40
# you are over weight

# %%
age=int(input("enter your age"))
weight=int(input("enter your weight:"))
if(age<18 or weight<=50):
  print("you are minor")
elif(age>=18 and age<=79):
  print("you ARE young")
elif(age>=80 and weight<=80):
  print("you can sit")
else:
  print("you can sit on rollacoaster")
# Out:
# enter your age18
# enter your weight:40
# you are minor

# %%
#practice
number=int(input("enter your num"))
if(number%2==0):
  print("even")
else:
  print("odd")
# Out:
# enter your num6
# even
