# %%
name="rehan"
teacher_name="rehan"
print(name)
print(teacher_name) #same location
# Out:
# rehan
# rehan

# %%
list_methods = [method for method in dir(list) if not method.startswith('__')]
print(list_methods)
