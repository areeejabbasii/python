# %%
  #data types topic

# %% [markdown]
# intellicense

# %% [markdown]
# ' abbbasi' "123434 "
# these are strings

# %%
#built in function of python
print("hello ")
# Out:
# hello

# %%
my_name :str="abbasi"

# %% [markdown]
# DRY dont repeat your self

# %%
my_name='areej'
my_name="abbasi"
print(my_name)
# Out:
# abbasi

# %% [markdown]
# top to bottom
# left to right

# %%
#input function #built in function
input("enter your name")
# Out:
# enter your nameareej abbasii
# 'areej abbasii'

# %%
my_name :str=input("please enter your name")
print(my_name)
# Out:
# please enter your nameareej abbasii
# areej abbasii

# %%
first_number:int=45
second_number:int=56
result=first_number+second_number
print(result)
# Out:
# 101

# %%
first_number:int="areej"
second_number:int="abbasi"
result=first_number +" "+second_number
print(result)
# Out:
# areej abbasi

# %%
print(8/4) #answer
# Out:
# 2.0

# %%
print(9%4)
# Out:
# 1

# %%
print(9//4) #whole number
# Out:
# 2

# %%
print(13//4)
# Out:
# 3

# %%
first_number =float(input("enter first number"))
second_number =float(input("enter second number"))
result=first_number+second_number
print(result)
# Out:
# enter first number4.9
# enter second number4.5
# 9.4

# %%
first_number=input()
print(type(first_number))
# Out:
# 45
# <class 'str'>

# %%
 num="4"
first_number=int(num)
print(type(first_number))
num1="5"
second_number=int(num1)
# Out:
# <class 'int'>

# %% [markdown]
# input by default consider string

# %%
#FORMAT STRING
first_name:str="areej"
last_name:str="abbasii"
age:int=18
print(f"my name is {first_name} {last_name}.my age is{age}")
#other method
print("my name is",first_name,last_name, "my age is",age)
# Out:
# my name is areej abbasii my age is 18

# %%
n="piaic45"
print(f"dear{name},")
print(f"your addmission is confirmed your roll num is {roll_no}.")
print(f"thank you")ame="areej"
roll_no
# Out:
# dearareej,
# your addmission is confirmed your roll num is piaic45.
# thank you

# %% [markdown]
# first last age string bnana homework

# %%
print("dear{}:",format(name))
# Out:
# dear{}: areej

# %%
user_name:str="areej"
user_age:int=int(input("please enter your age:",))
print(user_name)

# %%
first_name:str="areej"
last_name:str="abbasii"
age:int=19
print(f"my name is {first_name} {last_name}.my age is {age}")
# Out:
# my name is areej abbasii.my age is 19
