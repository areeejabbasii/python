# %% [markdown]
# ***function***
# because it prevent us from repitition
#  we
#   def function_name(parameteres):

# %%
print('salam everyone!')

# %%
def function_name(parameter):
  return value

# %% [markdown]
# lets greet through **function**

# %%
def greet():
  print('hello')
greet()
# Out:
# hello

# %% [markdown]
# lets create a function with parameter

# %%
def greet(name):
  print(f"hello {name}")
greet("hamzah")
greet("abbasi")

# %% [markdown]
# calling function

# %%
def add_two(a=10,b=20):
  c=a+b
  return c
add_two(10,20)
'''backup value 10,20 output 3 ai ga '''

# %% [markdown]
# define default parameters

# %%
def greet_with_default(name="areej"):
  print(f"hello{areej}")
'''lets call the function'''
greet_with_default("hamza")

# %% [markdown]
# assignment  calculator
# sub multiply

# %%
print("step1:boil water")
print("step2:add milk")
print("step3:add patti")
print("step4:serve without sugar")
tea1="drink"

# %%
print("step1:boil water")
print("step2:add milk")
print("step3:add patti")
print("step4:serve without sugar")
tea2="drink"
'''thats way we use funtion '''

# %%
def make_tea():

# %%
def make_tea():
print("step1:boil water")
print("step2:add milk")
print("step3:add patti")
print("step4:serve without sugar")
return"chaii"
print("stepx:washcup")
tea1=make_tea()
print(f"{tea1} for bahii")

# %% [markdown]
# return last code in function
#
#
# example online attendence

# %%
def make_tea():
print("step1:boil water")
print("step2:add milk")

print("step3:add patti")
print("step4:serve without sugar")


tea2=make_tea()
print(f"{tea2} for bahii")
'''jb kuch return ni krta tb none ata'''

# %%
def  call_llm(prompt):
print("user :{prompt}")
  return"Ai:hello how can i assist you?"
response=call_llm(prompt="hello,my name is areej")  'keyword argument'
print(response)
'''argument:parameters value is called argument''

# %%
import random
def roll_dice(limit=6):
 return random.randint(1,limit)
print(roll_dice(12))
print(roll_dice(24))

# %% [markdown]
# randint:randominteger
