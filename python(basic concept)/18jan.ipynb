# %%
''''tuple syntax'''
coordinates=(4,6)
print(coordinates)
'''other syntax'''
other_num=4,6,7,8
print(other_num)
only_one_value=(4) '''its not consider tuple. if this  is tuple it should be seprated by commas'''
'''DRy:donot repeat yourself'''
''''BUILT IN FUCTION '''
person1_salary=50000000
person2_salary=890000000
person3_salary=5000000
person4_salary=890000000
person5_salary=500000
person6_salary=89000
after_tax=person1_salary-10000
after_tax=person2_salary-1000000
'''''this consume time'''
def greeting():''''without parameter'''
    return"hii there, its me from  hr"
print(greeting())
'''''without parameters hum  nae ik ik kr kae dna hoga'''
def calculate_tax(person_salary)
 return person_salary-100000
 def add (a,b):
    result=a+b
    return result
    result=add(10,20)
    print(result)
    def multiply(a,b):
        result=a*b
    print(result)
    ''''return'''
    def greet():
        print("hello")
    greet()
    result=greet() ''''output:none'''
    print("hello")
 def greet():
    print("areej abbasi")
    return "helllo"
    result=greet()
    print(result )''''return function call ko value dae ga'''
def add():
    a=10
    b=20
    result=a+b
    return result
    '''add() use ni kr rae'''
    some_result=add()
    print(f"i am using{some_result}")
'''''also write print(f"i am using here{add()})'''
'''if we are not using return than nothing should happening'''
'''only one value  return multiple returns not allowed'''

# %%
'''parameter'''
def greet_01():
  return "hello" '''not possible for many person'''
print(f"greet_01()")

# %%
def greet_02(student_name):
  return f"hello {student_name}"
print(greet_02("rehan"))
print(greet_02("usman"))
# Out:
# hello rehan
# hello usman

# %% [markdown]
# **practice**

# %%
friends=["rehan","usman"]

print(f"heelo {friends[0]} you are invited")
print(f"heelo {friends[1]} you are invited")
''''this is not possible for 89 friends'''''
'''we use loops'''

# %%
'''for loop,while loop'''
friends=["rehan","usman","musa"]
for friend in friends:

  print(f"hello{friend} you  invited")
# Out:
# hellorehan you  invited
# hellousman you  invited
# hellomusa you  invited

# %%
'''for loop,while loop'''
friends=["rehan","usman","musa","wania","areej","ibtisam"]
for friend in friends[0:3]:
   '''slicing'''

   print(f"hello {friend} you  invited ")
# Out:
# hellorehan you  invited
# hellousman you  invited
# hellomusa you  invited

# %% [markdown]
#  '''friend is loop varible it run and also destroy there'''
#
# ---

# %%
'''range (st_pt,end-pt,step)'''
for i in range(1,11):
  print(i)
  list(range(1,11,2))

# %% [markdown]
# '''friend is loop varible it run and also destroy there'''
#   '''start point, end point'''

# %%
''''enumrate'''
friends=["rehan","usman","musa","wania","areej","ibtisam"]
for friend in friends:
  print(value)
  print(type(value))

# %%
'''print(enumerate(iterable))'''

# %%
result=enumrate(friends)
print(next(result))

# %%
'''tuple unpacking'''
'''we can done also by indexing'''
i,name=(1,"rehan")
print(i)
print(name)
# Out:
# 1
# rehan

# %%
friends=["rehan","usman","musa","wania","areej","ibtisam"]
for i ,name in enumerate(friends):
  if  name =="usman":
    continue
  print(f"index is {i} for value:{name}")
# Out:
# index is 0 for value:rehan
# index is 2 for value:musa
# index is 3 for value:wania
# index is 4 for value:areej
# index is 5 for value:ibtisam

# %%
friends=["rehan","usman","musa","wania","areej","ibtisam"]
for i ,name in enumerate(friends):
  if  name =="usman":
    break
  print(f"index is {i} for value:{name}")

# %%
friends=["rehan","usman","musa","wania","areej","ibtisam"]
for i ,name in enumerate(friends):
  if  name =="usman":
    break
  print(f"index is {i} for value:{name}")

# %%
friends=["rehan","usman","musa","wania","areej","ibtisam"]
for i in range(0,len(friends)):
  if  i==3:
    break
  print(f"index is {i} for value:{friends[i]}")
# Out:
# index is 0 for value:rehan
# index is 1 for value:usman
# index is 2 for value:musa

# %% [markdown]
# for loop use when we know about ending point

# %%
'''while("you have fish")
  keep eating'''

# %%
count=0
while count<6:
  print("count is :",count)
  count+=1
# Out:
# count is : 0
# count is : 1
# count is : 2
# count is : 3
# count is : 4
# count is : 5
