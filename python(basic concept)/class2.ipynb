# %%
print("hello world")
# Out:
# hello world

# %%
fav_celebrity="99999999"
print(fav_celebrity)
fav_num=9
important_no="seventy_two"
print(important_no)
# Out:
# 99999999
# seventy_two

# %%
print("hello areej")
# Out:
# hello areej

# %%
fav_celebrity ="hamzah syed"
print(fav_celebrity)
print(fav_celebrity)
print(fav_celebrity)
print(fav_celebrity)
# Out:
# hamzah

# %%
sentence= "my name is "
name="abbasi"
print(sentence + name)
# Out:
# my name is abbasi

# %%
sentence="my brother "
name="safiii"
print(sentence+name)
# Out:
# my brother safiii

# %%
name="areej "
gender="female"
print(name + gender)
# Out:
# areej female

# %% [markdown]
# *concatenation*
