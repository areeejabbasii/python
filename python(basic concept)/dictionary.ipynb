# %%
#key:values pair
dict={
    "name":"areej",
    "rollno"  :45,
    "learning":"coding",
}
print(dict)
info={
    "name":"safii",
    "rollno":45,

}
print(info)
# Out:
# {'name': 'areej', 'rollno': 45, 'learning': 'coding'}
# {'name': 'safii', 'rollno': 45}

# %%
inf={
    "name":"areej",
    "topics":("dict","set"), #no order
    #mutable
    #does not allow duplicate key
    "subjects" : ["python","javascript","java"],
}
inf["name"]="abbasii"
inf["name"]="areek"
print(inf["name"])
print(type(inf))
# Out:
# areek
# <class 'dict'>

# %%
null_dict={}
print(null_dict)
# Out:
# {}

# %%
student={
    "name":"rehan",
    "subject" :{
        "physics":56,
       "chem":89 ,
        "math":90,
    }
}
print(student["subject"]["chem"])
# Out:
# 89
