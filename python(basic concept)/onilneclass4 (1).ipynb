# %%
is_hungry=True
burger_lover=False
pizza_lovers=True
      #true      #true           #false
if(is_hungry and (burger_lover or pizza_lovers)): #first and
 print("lets order")
elif(is_hungry): #true7
  print("lets go to sleep")
else:
  print("not hungry")  #first "and" ko phir" or" ko jb brackets ni hoge
# Out:
# lets order

# %%
is_hungry=True
burger_lover=False
pizza_lovers=True
      #true      #true           #false
if(is_hungry and burger_lover or pizza_lovers): #first and
 print("lets order")
elif(is_hungry): #true7
  print("lets go to sleep")
else:
  print("not hungry")  #first "and" ko phir" or" ko jb brackets ni hoge
# Out:
# lets order

# %%
#why list are important
from typing import list
#shopping list
item_1:str="cake"
item_2:str="eggs"
item_3:str="juice"
item_4:str="oil"
item_5:str="yougrt"
print(item_1,item_2)

# %%
#list index
item=["cake","yougrt","biscuit","ghee"]
        #0    1       2        3
print(item)
task:list[str]=["teach","finish a project","dinner","sleep"]
print(task[3]) #if limit excceed
print(task[2])
#find the length list
print(len(task)) # length 1 sae count krta

# %%
#list slicing

task:list[str]=["teach","finish a project","dinner","sleep","course"]
print(task[0:4]) #if limit excceed
#for one item[]
#find the length list

# %%
#checkin member ship
#list index
item=["cake","yougrt","biscuit","oil","juice"]
        #0    1       2        3
print("oil" in item)
#if i remove oli
#if i remove other
print("flour" in item) #false

# %%
#adding or removing iteam from list
#list index
item=["cake","yougrt","biscuit","ghee"]
        #0    1       2        3
print(item.append("flour")) #extend
#remove
print(item.remove("cake"))
#inserting  and removing item in list
#move hoa
print(item.insert(2,"flour")) #move hoa
#pop
print(item.pop(3))
