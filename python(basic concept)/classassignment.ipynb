# %%
print("hello world") #first program

# %%
first_name:str=input("enter first num")
last_name:str=input("enter last num")
print(first_name+last_name)
# Out:
# enter first numareej
# enter last numabbasi
# areejabbasi

# %%
a:int=int(input("enter first num"))
b:int=int(input("enter second num"))
sum=a+b
print("the sum of a and b is :",sum)
sub=a-b
print(" the sub of a and b is:",sub)
product=a*b
print("the product of a and b is:",product)
division=a/b
print(" the division of a and b is:", division)
exp=a**b
print("the exp  of a and b is:",exp)
floor=a//b
print(" the floor of a and b is:",floor)
mod=a%b
print(" the mod of a and b  is :",mod)
# Out:
# enter first num4
# enter second num6
# the sum of a and b is : 10
#  the sub of a and b is: -2
# the product of a and b is: 24
#  the division of a and b is: 0.6666666666666666
# the exp  of a and b is: 4096
#  the floor of a and b is: 0
#  the mod of a and b  is : 4

# %%
student_name="areej abbasii"
roll_no="PIAIC123"
class_venue="LTC HALL"
print(f"Dear {student_name}")
print(f"Thank you for regestration in the Agentic AI course ")
print(f"your rollnumber is {roll_no}")
print(f"your class will be held in the air university {class_venue} on saturdays at 02:00 pm to 06:00pm")
print("")
# Out:
# Dear areej abbasii
# Thank you for regestration in the Agentic AI course
# your rollnumber is PIAIC123
# your class will be held in the air university LTC HALL on saturdays at 02:00 pm to 06:00pm

# %% [markdown]
# *   Source Code → (via Python Compiler) → Bytecode
# Bytecode → (via PVM) → Machine Code
#
#
# *   PVM PYTHON VIRTUAL MACHINE
# *
