# %%
name:str="rehan"
print(id(name))
# Out:
# 137839878929264

# %%
name:list[str]=["rehan"]
print(f' Adress of list {id(name)}')
print(f'adress of first item of list{id(name[0])}')
# Out:
#  Adress of list 137838987693248
# adress of first item of list137839878929264

# %% [markdown]
# #shallow and deep

# %%
student_grades=[
    ["areej",85,90,67], #first element 0 infdex

    ["hamzah",67,90,80], #second element 1 index

]
print(student_grades[0])
#print(student_grades[1])
print(student_grades[1][0]) #[0] specific
# Out:
# ['areej', 85, 90, 67]
# hamzah

# %%
##control flows

# %%
#comparision\
#equality check ==
print(5==6)
print(5==5)
print(5=='5')
# Out:
# False
# True
# False

# %%
# !not=
print(6!=7)
# Out:
# True

# %%
name1="rehan"
name2="rehan"
#ascii code change A=65 a=92
print(name1!=name2)
# Out:
# False

# %%
#< >
num=int(input("enter your num"))
num1=int(input("enter your num"))
print(num<num1)
print(num>num1)
# Out:
# enter your num5
# enter your num7
# True
# False

# %%
#< >
num=int(input("enter your num:"))
num1=int(input("enter your num:"))
print(num<=num1)
print(num>=num1)
# Out:
# enter your num6
# enter your num8
# True
# False

# %%
#control flow #if #ifelif  #if_else
age=int(input("enter your age :"))
if(age>=18):
  print("you are allowed")

else:
  print("wait for next year")
# Out:
# enter your age18
# you are allowed

# %%
#control flow #if #ifelif  #if_else
age:int=int(input("enter your age"))
if(age>=18): #:block #space
  print("you are allowed") #this will be executed if expression is true
# Out:
# enter your age18
# you are allowed

# %%
# multiple condition but independent
age:int=int(input("enter your age:"))
if(age<=6):
   print(" issue birth certificate")
elif(7<= age<=17): #left to right
   print(" issue domicile")
elif(age>=18):
  print(" issue cnic")
else:
  print("sorry ")
# Out:
# enter your age:18
#  issue cnic

# %%
name="rehan"
if(name):
  print("hello")
elif(name):
  print("hii")
# Out:
# hello

# %%
name=" " #""
if(name):
  print(name)

# %% [markdown]
# falsy  value
#
# 1.   0
#
# 1.   empty dictioary
# 2 empty set
#
# 2.   empty string
#
#
# .

# %%
#empty string
value=" "
if(value):
  print("this is true")
else:
  print("this is falsy value")
# Out:
# this is true

# %%
value=0
if(value):
  print("this is true")
else:
  print("this is falsy value")

# %%
value:list=[]
if(value):
  print("this is true")
else:
  print("this is falsy value")
# Out:
# this is falsy value

# %%
#multiple condition but dependent

nationality=input("enter your nationality")
if nationality.lower()=="pakistani":
  age=int(input("enter your age :"))
  if(age>=18):
    print("cnic issues") #dry run
  else:
     print("nadra only issue pakistani cnic")
# Out:
# enter your nationalitypakistani
# enter your age :18
# cnic issues

# %%
#logical operator #multipule condition
#and or not
name="rehan"
age=5
     #True &false and (multiplication)
     #false and false=false
     #true and true =true
     #true=1
     #false=0
if (name=="rehan" and age>6): #and shall evaluate true iff both condition evaluate true

  print("if block executed")
else:
  print("else block")
# Out:
# else block

# %%
#OR  (addition+)
#false false =false
#true true=true
 #logical operator #multipule condition
#and or not
name="rehan"
age=5
     #True &false and (multiplication)
     #false and false=false
     #true and true =true
     #true=1
     #false=0
if (name=="rehan" or age>6): #and shall evaluate true iff both condition evaluate true
     print(f'first condition: {name =="rehan"},second condition:{age>4}')
     print("if block executed")
else:
  print("else block")
# Out:
# first condition: True,second condition:True
# if block executed

# %%
#logical operator #multipule condition
#and or not
name="rehan"
age=5
     #True &false and (multiplication)
     #false and false=false
     #true and true =true
     #true=1
     #false=0
if  not(name=="rehan" and age>6): #and shall evaluate true iff both condition evaluate true

  print("if block executed")
else:
  print("else block")
# Out:
# if block executed
