# %% [markdown]
# 1.parameterized
#
# 2.parameterless
#
# 3.without return
#
# 4.with return

# %% [markdown]
# 1.positional argument

# %%
def  add(first_num:int,second_num:int) ->int:'''parameter'''
  return first_num+second_num
  pass
result:int=add(5,8)'''arguments'''
''' function call'''

# %%
def  add(first_num:int,second_num:int) ->int:
  return first_num+second_num
  pass
  a=6
  b=5
result:int=add(a,b)
''' function call'''

# %%
def greet (first_name ,last_name):
  print(f'hi {first_name} {last_name}')
greet('john','doe')
greet('doe','john')

# %%
'''position error'''
def greet (first_name ,last_name):
  print(f'hi {first_name} {last_name}')
  first='john'
  second='doe'
greet(first)

# %%
def add (*args):
  print("allargs")
  print(type(args))
  total=0
  for num in args:
    total+=num
  return total
  pass
print(add(1,2,3,4,5,6))
# Out:
# allargs
# <class 'tuple'>
# None

# %%
print(add(1,5))
'''this give no error'''

# %%
num_list=[1,2,3,4]
result=add(*num_list)
'''*unpacked'''
print(result)

# %%
'''keyword arrgument'''
def greet(name,age):
  print(f"the namew is {name} and age is {age}")
greet(age=25,name="john")
'''we define keyword argument thats way no error come'''

# %%
'''keyword arrgument'''
def greet(name,age):
  print(f"the namew is {name} and age is {age}")
greet(25,"john")
'''we define keyword argument thats way no error come'''
# Out:
# the namew is 25 and age is john
# 'we define keyword argument thats way no error come'

# %%
'''position error'''
def greet (first_name ="muhammad",last_name):
  print(f'hi {first_name} {last_name}')

greet(first)

# %%
'''position error'''
def greet (last_name,first_name='abbasi'):
  print(f'hi {first_name} {last_name}')
'''keyword argument never comes before positional argum'''

greet('rehan')
# Out:
# hi abbasi rehan

# %%
'''position error'''
def greet (last_name,first_name='abbasi'):
  print(f'hi {first_name} {last_name}')
'''keyword argument never comes before positional argum'''

greet('rehan',first_name='abc')
'''by default ko ni lae ga'''

# %%
def greet(**kwargs):
  print(kwargs)
  print(type(kwargs))
  greet(name="john",age=25)

# %% [markdown]
# keywors argument

# %%
def display_info(*args,**kwargs):
  print("positional arguments:", args)
  print("key word argument:", kwargs)
  display_info(1,2,3,name="areej")

# %%
def greet(name,dep):
  print(f"hii{name} your {dep} department")
greet(name="areej",dep="cs")
greet(dep="cs",name="areej")

'''positional argu
print('cs','jenny') yhis not make sense
what we can do
greet(name,dep='css)
name is positional'''

# %% [markdown]
# scopes in python

# %%
def add(a,b):
  a=200
  print("a:",a)
  print("b:",b)
a=6
b=8
add(12,22)
print("last output","a:",a,"b:",b)

# %%
def scope(a,b):
  print("a:",a)
  print("b:",b)
a=6
b=8
scope(12,22)
print("last output","a:",a,"b:",b)

# %%
def scope(a,b):
  a=45
  print("a:",a)
  print("b:",b)
a=6
b=8

scope(12,22)
print("last output","a:",a,"b:",b)
# Out:
# a: 45
# b: 22
# last output a: 38 b: 8

# %%
first_name="muhammad"
def greet(last_name=):
  print(f"hi {first_name}{last_name}")
greet("ghani")

# %%
def greet():
  name="muhammad" '''local scope'''
  print(f"hi {name}")
greet()
print(name)
# Out:
# hi muhammad
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-017c8ea70272> in <cell line: 0>()
#       3   print(f"hi {name}")
#       4 greet()
# ----> 5 print(name)
#
# NameError: name 'name' is not defined

# %%
def scope(c,d):

  print("a:",a)
  print("b:",b)
a=6
b=8

scope(12,22)
print("last output","a:",a,"b:",b)
# Out:
# a: 6
# b: 8
# last output a: 6 b: 8

# %%
def func_2():
  name="musa"
  print("name:",name)
name="rehan"
func_2()
print("name:",name)
# Out:
# name: musa
# name: rehan

# %%
name="rehan"
def func_2():
  global name
  name="musa"
  print("name:",name)

func_2()
print("name:",name)
# Out:
# name: musa
# name: musa

# %%
def func_2():
  global name2
  '''acessable because of global keyword'''
  name2="musa"
  print("name:",name2)
func_2()
print(name2)

# %% [markdown]
# recursion

# %%
'''write code there
 from github also fabinocio series'''

# %% [markdown]
# lambda

# %%
'''no name
lambda argument : experssion'''
square=lambda x:x**2
'''we cant call lambda
'''
