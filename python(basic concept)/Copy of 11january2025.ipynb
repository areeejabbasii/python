# %%
#membership operators (in,notin) #iterable
#from typing import list
fruits:list[str]=["apple","banana"]

# %%
if "apple" in fruits:
  print("in the list")
# Out:
# in the list

# %%
name:str="areej"
print("a" in name)
# Out:
# True

# %%
a=[1,2,3]
b=a
print(a is b)
c=[1,2,3] #memory location change ha #new address
print(c is b)
print("identity",a is c)
print("equality",a==c)
# Out:
# True
# False
# identity False
# equality True

# %%
print("memory ID of a",id(a))
print("memory ID of b",id(b))
print("memory ID of c", id(c))
#isnot iska reverse ha
# Out:
# memory ID of a 135805184773248
# memory ID of b 135805184773248
# memory ID of c 135805183537920

# %%
#data stucture
#big o notation
#time and space complexity

# %%
student_score=[
    ["areej",565],
    ["usman",100] # not efficent thats way we use dictnory
]

# %%
#dictionart (key ,valuepair)
student_score={
    "rehan":56,
     "usman": 67,
        }
#keys shall be unique (avoid repetition)
#keys can be of any data type that is immutable(str,integer,float,boolean)
#values can be any data type

# %%
from typing import Any
student:dict[int,list{int}| dict{str,int}]={
    1 :[1,2,3], #list
    2 : {"rehan":45} #dic
}
#key:value

# %%
student_score:dict[str,int]={
    "areej":56,
    "abbasi":34,
    "usman":90
}

# %%
student_dict={
    "rehan":87,
    "rehan":0
}

# %%
#() #tuple
#[] #list
#{} #dic

# %%
total_score:int=32
total_score="rehan"

# %%
studen
