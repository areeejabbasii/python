# %%
#list:a built-in data store set of values : we can store element of different types(integer,float,char)
#marks=94.4
#marks1=45.9
#marks2=89.6
#marks3=56.9
#marks4=78.7
#this consume our alot of time thats way we use list
marks=[12.6,13.7,15.8] #list
print(marks)
print(type(marks)) #marks[0]
print(marks[0]) #indexing
print(len(marks))#length of string
# Out:
# [12.6, 13.7, 15.8]
# <class 'list'>
# 12.6
# 3

# %%
student=["areej",90.9,17,"RWP"]
print(student)
student[0]="abbasii"
print(student) #mutable
# Out:
# ['areej', 90.9, 17, 'RWP']
# ['abbasii', 90.9, 17, 'RWP']

# %%
#string:immutable
#list:mutable #access #change
student=["safiullah",89.8,18,"mirpur"]
student[0]="sana"
print(student)
# Out:
# ['sana', 89.8, 18, 'mirpur']

# %%
#listslicing
marks=[85,94,67,90]
print(marks[1:4])
print(marks[1:])
#negative index
marks1=[56,78,89,9,67]
print(marks1[-3:-1])
# Out:
# [94, 67, 90]
# [94, 67, 90]
# [89, 9]

# %%
#list method
list=[1,2,3]
list.append(4)
print(list)
# Out:
# [1, 2, 3, 4]

# %%
#sort
list=[2,9,8,6]
list.sort()
print(list)
# Out:
# [2, 6, 8, 9]

# %%
#reverse sort
list=[4,5,9,8]
list.sort(reverse=True)
print(list)
# Out:
# [9, 8, 5, 4]

# %%
list=["apple","banana","orange"]
list.sort(reverse=True)
print(list)
#example
list1=['a','b','c','d','e']
list1.sort(reverse=True)
print(list1)
# Out:
# ['orange', 'banana', 'apple']
# ['e', 'd', 'c', 'b', 'a']

# %%
#reverse
list=['a','b','u','i']
list.reverse()
print(list)
#insert same as append but this insert in particular index
#list.insert(index,element)
list1=[1,2,3,5]
list1.insert(1,7)
print(list1)
# Out:
# ['i', 'u', 'b', 'a']
# [1, 7, 2, 3, 5]

# %%
list=[1,2,1,2]
list.remove(2) # this remove first coming 2
print(list)
# Out:
# [1, 1, 2]

# %%
#pop same as remove but this remove from particular index
list=[1,5,7,8]
list.pop(2)
print(list)
# Out:
# [1, 5, 8]

# %%
#tuple in python
#tuple is immutable just like string
tup=(2,7,9,8)
print(type(tup))
print(tup[0])
print(tup[2])
#tup[0]=6 this is not allowed in tuple because tuple are immutable
# Out:
# <class 'tuple'>

# %%
tup(1,) # if i remove , python consider integer (,compulsaory)
print(tup)
print(type(tup))

# %%
#slicing in tuple
tup=(1,2,4,9,7)
print(tup[1:4])
# Out:
# (2, 4, 9)

# %%
#tuple method
tup=(1,4,6,8)
print(tup.count(4))
# Out:
# 1

# %%
#practice
movies=[]
movies1:str=input("enter your first fvt movies:")
movies2 :str=input("enter your second fvt movies:")
movies3 :str=input("enter your three fvt movies:")
movies.append(movies1)
movies.append(movies2)
movies.append(movies3)
print(movies)
# Out:
# enter your first fvt movies:junoon
# enter your second fvt movies:tare zameen pr
# enter your three fvt movies:jan
# ['junoon', 'tare zameen pr', 'jan']

# %%
list1=[1,2,3,2,1]
copy_list1=list1.copy()
copy_list1.reverse()

if(copy_list1==list1):
   print("palindrome")
else:
  print("not palindrome")
# Out:
# palindrome

# %%
list=[1,3,6]
copy_list=list.copy()
copy_list.reverse()
if(copy_list==list):
  print("palindrom")
else:
  print("not palindrom")
# Out:
# not palindrom

# %%
tup=("C","D","A","A","B","B","A")
tup1=tup.count("A")
print(tup1)
# Out:
# 3

# %%
list=["C","D","A","A","B","B","A"]
list.sort()
print(list)
# Out:
# ['A', 'A', 'A', 'B', 'B', 'C', 'D']
